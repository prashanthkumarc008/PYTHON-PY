# %%
emp={'eid':101,
    'ename':'rahul',
    'esal':45000.5,
    'loc':'wayanad'}
print(emp)
print(emp['eid'])
print(emp['ename'])
print(emp['esal'])
print(emp['loc'])

for key in emp.values():
    print(key)
# Out:
# {'eid': 101, 'ename': 'rahul', 'esal': 45000.5, 'loc': 'wayanad'}
# 101
# rahul
# 45000.5
# wayanad
# eid
# ename
# esal
# loc
